# %% [markdown]
# # Lab | SQL Queries 9
#
# In this lab, you will be using the [Sakila](https://dev.mysql.com/doc/sakila/en/) database of movie rentals. You have been using this database for a couple labs already, but if you need to get the data again, refer to the official [installation link](https://dev.mysql.com/doc/sakila/en/sakila-installation.html).
#
# The database is structured as follows:
# ![DB schema](https://education-team-2020.s3-eu-west-1.amazonaws.com/data-analytics/database-sakila-schema.png)
#
# ### Instructions
#
# In this lab we will find the customers who were active in consecutive months of May and June. Follow the steps to complete the analysis.
#
# - Create a table `rentals_may` to store the data from rental table with information for the month of May.
# - Insert values in the table `rentals_may` using the table rental, filtering values only for the month of May.
# - Create a table `rentals_june` to store the data from rental table with information for the month of June.
# - Insert values in the table `rentals_june` using the table rental, filtering values only for the month of June.
# - Check the number of rentals for each customer for May.
# - Check the number of rentals for each customer for June.
# - Create a Python connection with SQL database and retrieve the results of the last two queries (also mentioned below) as dataframes:
#
#   - Check the number of rentals for each customer for May
#   - Check the number of rentals for each customer for June
#
#     **Hint**: You can store the results from the two queries in two separate dataframes.
#
# - Write a function that checks if customer borrowed more or less films in the month of June as compared to May.
#
#   **Hint**: For this part, you can create a join between the two dataframes created before, using the merge function available for pandas dataframes. Here is a link to the documentation for the [merge function](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html).

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import getpass  # To get the password without showing the input

# %% [markdown]
# ##### Prepare SQL connection

# %%
password = getpass.getpass()
connection_string = 'mysql+pymysql://root:' + password + '@localhost/bank'
engine = create_engine(connection_string)
# %load_ext sql
# %sql {connection_string}
# Out:
#  ··········

# %% [markdown]
# **Your code goes here! :**

# %% [markdown]
# 1.

# %%
#Hacer Querie que irá dentro de la tabla

# %%
# %%sql
# select *
# from sakila.rental
# where month(rental_date) = 5;
# Out:
#  * mysql+pymysql://root:***@localhost/bank
# 1156 rows affected.
# [(1, datetime.datetime(2005, 5, 24, 22, 53, 30), 367, 130, datetime.datetime(2005, 5, 26, 22, 4, 30), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (2, datetime.datetime(2005, 5, 24, 22, 54, 33), 1525, 459, datetime.datetime(2005, 5, 28, 19, 40, 33), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (3, datetime.datetime(2005, 5, 24, 23, 3, 39), 1711, 408, datetime.datetime(2005, 6, 1, 22, 12, 39), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (4, datetime.datetime(2005, 5, 24, 23, 4, 41), 2452, 333, datetime.datetime(2005, 6, 3, 1, 43, 41), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (5, datetime.datetime(2005, 5, 24, 23, 5, 21), 2079, 222, datetime.datetime(2005, 6, 2, 4, 33, 21), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (6, datetime.datetime(2005, 5, 24, 23, 8, 7), 2792, 549, datetime.datetime(2005, 5, 27, 1, 32, 7), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (7, datetime.datetime(2005, 5, 24, 23, 11, 53), 3995, 269, datetime.datetime(2005, 5, 29, 20, 34, 53), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (8, datetime.datetime(2005, 5, 24, 23, 31, 46), 2346, 239, datetime.datetime(2005, 5, 27, 23, 33, 46), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (9, datetime.datetime(2005, 5, 25, 0, 0, 40), 2580, 126, datetime.datetime(2005, 5, 28, 0, 22, 40), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (10, datetime.datetime(2005, 5, 25, 0, 2, 21), 1824, 399, datetime.datetime(2005, 5, 31, 22, 44, 21), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (11, datetime.datetime(2005, 5, 25, 0, 9, 2), 4443, 142, datetime.datetime(2005, 6, 2, 20, 56, 2), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (12, datetime.datetime(2005, 5, 25, 0, 19, 27), 1584, 261, datetime.datetime(2005, 5, 30, 5, 44, 27), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (13, datetime.datetime(2005, 5, 25, 0, 22, 55), 2294, 334, datetime.datetime(2005, 5, 30, 4, 28, 55), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (14, datetime.datetime(2005, 5, 25, 0, 31, 15), 2701, 446, datetime.datetime(2005, 5, 26, 2, 56, 15), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (15, datetime.datetime(2005, 5, 25, 0, 39, 22), 3049, 319, datetime.datetime(2005, 6, 3, 3, 30, 22), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (16, datetime.datetime(2005, 5, 25, 0, 43, 11), 389, 316, datetime.datetime(2005, 5, 26, 4, 42, 11), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (17, datetime.datetime(2005, 5, 25, 1, 6, 36), 830, 575, datetime.datetime(2005, 5, 27, 0, 43, 36), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (18, datetime.datetime(2005, 5, 25, 1, 10, 47), 3376, 19, datetime.datetime(2005, 5, 31, 6, 35, 47), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (19, datetime.datetime(2005, 5, 25, 1, 17, 24), 1941, 456, datetime.datetime(2005, 5, 31, 6, 0, 24), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (20, datetime.datetime(2005, 5, 25, 1, 48, 41), 3517, 185, datetime.datetime(2005, 5, 27, 2, 20, 41), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (21, datetime.datetime(2005, 5, 25, 1, 59, 46), 146, 388, datetime.datetime(2005, 5, 26, 1, 1, 46), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (22, datetime.datetime(2005, 5, 25, 2, 19, 23), 727, 509, datetime.datetime(2005, 5, 26, 4, 52, 23), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (23, datetime.datetime(2005, 5, 25, 2, 40, 21), 4441, 438, datetime.datetime(2005, 5, 29, 6, 34, 21), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (24, datetime.datetime(2005, 5, 25, 2, 53, 2), 3273, 350, datetime.datetime(2005, 5, 27, 1, 15, 2), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (25, datetime.datetime(2005, 5, 25, 3, 21, 20), 3961, 37, datetime.datetime(2005, 5, 27, 21, 25, 20), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (26, datetime.datetime(2005, 5, 25, 3, 36, 50), 4371, 371, datetime.datetime(2005, 5, 31, 0, 34, 50), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (27, datetime.datetime(2005, 5, 25, 3, 41, 50), 1225, 301, datetime.datetime(2005, 5, 30, 1, 13, 50), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (28, datetime.datetime(2005, 5, 25, 3, 42, 37), 4068, 232, datetime.datetime(2005, 5, 26, 9, 26, 37), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (29, datetime.datetime(2005, 5, 25, 3, 47, 12), 611, 44, datetime.datetime(2005, 5, 30, 0, 31, 12), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (30, datetime.datetime(2005, 5, 25, 4, 1, 32), 3744, 430, datetime.datetime(2005, 5, 30, 3, 12, 32), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (31, datetime.datetime(2005, 5, 25, 4, 5, 17), 4482, 369, datetime.datetime(2005, 5, 30, 7, 15, 17), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (32, datetime.datetime(2005, 5, 25, 4, 6, 21), 3832, 230, datetime.datetime(2005, 5, 25, 23, 55, 21), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (33, datetime.datetime(2005, 5, 25, 4, 18, 51), 1681, 272, datetime.datetime(2005, 5, 27, 3, 58, 51), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (34, datetime.datetime(2005, 5, 25, 4, 19, 28), 2613, 597, datetime.datetime(2005, 5, 29, 0, 10, 28), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (35, datetime.datetime(2005, 5, 25, 4, 24, 36), 1286, 484, datetime.datetime(2005, 5, 27, 7, 2, 36), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (36, datetime.datetime(2005, 5, 25, 4, 36, 26), 1308, 88, datetime.datetime(2005, 5, 29, 0, 31, 26), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (37, datetime.datetime(2005, 5, 25, 4, 44, 31), 403, 535, datetime.datetime(2005, 5, 29, 1, 3, 31), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (38, datetime.datetime(2005, 5, 25, 4, 47, 44), 2540, 302, datetime.datetime(2005, 6, 1, 0, 58, 44), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (39, datetime.datetime(2005, 5, 25, 4, 51, 46), 4466, 207, datetime.datetime(2005, 5, 31, 3, 14, 46), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (40, datetime.datetime(2005, 5, 25, 5, 9, 4), 2638, 413, datetime.datetime(2005, 5, 27, 23, 12, 4), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (41, datetime.datetime(2005, 5, 25, 5, 12, 29), 1761, 174, datetime.datetime(2005, 6, 2, 0, 28, 29), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (42, datetime.datetime(2005, 5, 25, 5, 24, 58), 380, 523, datetime.datetime(2005, 5, 31, 2, 47, 58), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (43, datetime.datetime(2005, 5, 25, 5, 39, 25), 2578, 532, datetime.datetime(2005, 5, 26, 6, 54, 25), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (44, datetime.datetime(2005, 5, 25, 5, 53, 23), 3098, 207, datetime.datetime(2005, 5, 29, 10, 56, 23), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (45, datetime.datetime(2005, 5, 25, 5, 59, 39), 1853, 436, datetime.datetime(2005, 6, 2, 9, 56, 39), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (46, datetime.datetime(2005, 5, 25, 6, 4, 8), 3318, 7, datetime.datetime(2005, 6, 2, 8, 18, 8), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (47, datetime.datetime(2005, 5, 25, 6, 5, 20), 2211, 35, datetime.datetime(2005, 5, 30, 3, 4, 20), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (48, datetime.datetime(2005, 5, 25, 6, 20, 46), 1780, 282, datetime.datetime(2005, 6, 2, 5, 42, 46), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (49, datetime.datetime(2005, 5, 25, 6, 39, 35), 2965, 498, datetime.datetime(2005, 5, 30, 10, 12, 35), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (50, datetime.datetime(2005, 5, 25, 6, 44, 53), 1983, 18, datetime.datetime(2005, 5, 28, 11, 28, 53), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (51, datetime.datetime(2005, 5, 25, 6, 49, 10), 1257, 256, datetime.datetime(2005, 5, 26, 6, 42, 10), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (52, datetime.datetime(2005, 5, 25, 6, 51, 29), 4017, 507, datetime.datetime(2005, 5, 31, 1, 27, 29), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (53, datetime.datetime(2005, 5, 25, 7, 19, 16), 1255, 569, datetime.datetime(2005, 5, 27, 5, 19, 16), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (54, datetime.datetime(2005, 5, 25, 7, 23, 25), 2787, 291, datetime.datetime(2005, 6, 1, 5, 5, 25), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (55, datetime.datetime(2005, 5, 25, 8, 26, 13), 1139, 131, datetime.datetime(2005, 5, 30, 10, 57, 13), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (56, datetime.datetime(2005, 5, 25, 8, 28, 11), 1352, 511, datetime.datetime(2005, 5, 26, 14, 21, 11), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (57, datetime.datetime(2005, 5, 25, 8, 43, 32), 3938, 6, datetime.datetime(2005, 5, 29, 6, 42, 32), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (58, datetime.datetime(2005, 5, 25, 8, 53, 14), 3050, 323, datetime.datetime(2005, 5, 28, 14, 40, 14), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (59, datetime.datetime(2005, 5, 25, 8, 56, 42), 2884, 408, datetime.datetime(2005, 6, 1, 9, 52, 42), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (60, datetime.datetime(2005, 5, 25, 8, 58, 25), 330, 470, datetime.datetime(2005, 5, 30, 14, 14, 25), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (61, datetime.datetime(2005, 5, 25, 9, 1, 57), 4210, 250, datetime.datetime(2005, 6, 2, 7, 22, 57), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (62, datetime.datetime(2005, 5, 25, 9, 18, 52), 261, 419, datetime.datetime(2005, 5, 30, 10, 55, 52), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (63, datetime.datetime(2005, 5, 25, 9, 19, 16), 4008, 383, datetime.datetime(2005, 5, 27, 4, 24, 16), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (64, datetime.datetime(2005, 5, 25, 9, 21, 29), 79, 368, datetime.datetime(2005, 6, 3, 11, 31, 29), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (65, datetime.datetime(2005, 5, 25, 9, 32, 3), 3552, 346, datetime.datetime(2005, 5, 29, 14, 21, 3), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (66, datetime.datetime(2005, 5, 25, 9, 35, 12), 1162, 86, datetime.datetime(2005, 5, 29, 4, 16, 12), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (67, datetime.datetime(2005, 5, 25, 9, 41, 1), 239, 119, datetime.datetime(2005, 5, 27, 13, 46, 1), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (68, datetime.datetime(2005, 5, 25, 9, 47, 31), 4029, 120, datetime.datetime(2005, 5, 31, 10, 20, 31), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (69, datetime.datetime(2005, 5, 25, 10, 10, 14), 3207, 305, datetime.datetime(2005, 5, 27, 14, 2, 14), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (70, datetime.datetime(2005, 5, 25, 10, 15, 23), 2168, 73, datetime.datetime(2005, 5, 27, 5, 56, 23), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (71, datetime.datetime(2005, 5, 25, 10, 26, 39), 2408, 100, datetime.datetime(2005, 5, 28, 4, 59, 39), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (72, datetime.datetime(2005, 5, 25, 10, 52, 13), 2260, 48, datetime.datetime(2005, 5, 28, 5, 52, 13), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (73, datetime.datetime(2005, 5, 25, 11, 0, 7), 517, 391, datetime.datetime(2005, 6, 1, 13, 56, 7), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (74, datetime.datetime(2005, 5, 25, 11, 9, 48), 1744, 265, datetime.datetime(2005, 5, 26, 12, 23, 48), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (75, datetime.datetime(2005, 5, 25, 11, 13, 34), 3393, 510, datetime.datetime(2005, 6, 3, 12, 58, 34), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (76, datetime.datetime(2005, 5, 25, 11, 30, 37), 3021, 1, datetime.datetime(2005, 6, 3, 12, 0, 37), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (77, datetime.datetime(2005, 5, 25, 11, 31, 59), 1303, 451, datetime.datetime(2005, 5, 26, 16, 53, 59), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (78, datetime.datetime(2005, 5, 25, 11, 35, 18), 4067, 135, datetime.datetime(2005, 5, 31, 12, 48, 18), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (79, datetime.datetime(2005, 5, 25, 12, 11, 7), 3299, 245, datetime.datetime(2005, 6, 3, 10, 54, 7), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (80, datetime.datetime(2005, 5, 25, 12, 12, 7), 2478, 314, datetime.datetime(2005, 5, 31, 17, 46, 7), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (81, datetime.datetime(2005, 5, 25, 12, 15, 19), 2610, 286, datetime.datetime(2005, 6, 2, 14, 8, 19), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (82, datetime.datetime(2005, 5, 25, 12, 17, 46), 1388, 427, datetime.datetime(2005, 6, 1, 10, 48, 46), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (83, datetime.datetime(2005, 5, 25, 12, 30, 15), 466, 131, datetime.datetime(2005, 5, 27, 15, 40, 15), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (84, datetime.datetime(2005, 5, 25, 12, 36, 30), 1829, 492, datetime.datetime(2005, 5, 29, 18, 33, 30), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (85, datetime.datetime(2005, 5, 25, 13, 5, 34), 470, 414, datetime.datetime(2005, 5, 29, 16, 53, 34), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (86, datetime.datetime(2005, 5, 25, 13, 36, 12), 2275, 266, datetime.datetime(2005, 5, 30, 14, 53, 12), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (87, datetime.datetime(2005, 5, 25, 13, 52, 43), 1586, 331, datetime.datetime(2005, 5, 29, 11, 12, 43), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (88, datetime.datetime(2005, 5, 25, 14, 13, 54), 2221, 53, datetime.datetime(2005, 5, 29, 9, 32, 54), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (89, datetime.datetime(2005, 5, 25, 14, 28, 29), 2181, 499, datetime.datetime(2005, 5, 29, 14, 33, 29), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (90, datetime.datetime(2005, 5, 25, 14, 31, 25), 2984, 25, datetime.datetime(2005, 6, 1, 10, 7, 25), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (91, datetime.datetime(2005, 5, 25, 14, 57, 22), 139, 267, datetime.datetime(2005, 6, 1, 18, 32, 22), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (92, datetime.datetime(2005, 5, 25, 15, 38, 46), 775, 302, datetime.datetime(2005, 5, 31, 13, 40, 46), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (93, datetime.datetime(2005, 5, 25, 15, 54, 16), 4360, 288, datetime.datetime(2005, 6, 3, 20, 18, 16), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (94, datetime.datetime(2005, 5, 25, 16, 3, 42), 1675, 197, datetime.datetime(2005, 5, 30, 14, 23, 42), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (95, datetime.datetime(2005, 5, 25, 16, 12, 52), 178, 400, datetime.datetime(2005, 6, 2, 18, 55, 52), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (96, datetime.datetime(2005, 5, 25, 16, 32, 19), 3418, 49, datetime.datetime(2005, 5, 30, 10, 47, 19), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (97, datetime.datetime(2005, 5, 25, 16, 34, 24), 1283, 263, datetime.datetime(2005, 5, 28, 12, 13, 24), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (98, datetime.datetime(2005, 5, 25, 16, 48, 24), 2970, 269, datetime.datetime(2005, 5, 27, 11, 29, 24), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (99, datetime.datetime(2005, 5, 25, 16, 50, 20), 535, 44, datetime.datetime(2005, 5, 28, 18, 52, 20), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (100, datetime.datetime(2005, 5, 25, 16, 50, 28), 2599, 208, datetime.datetime(2005, 6, 2, 22, 11, 28), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (101, datetime.datetime(2005, 5, 25, 17, 17, 4), 617, 468, datetime.datetime(2005, 5, 31, 19, 47, 4), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (102, datetime.datetime(2005, 5, 25, 17, 22, 10), 373, 343, datetime.datetime(2005, 5, 31, 19, 47, 10), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (103, datetime.datetime(2005, 5, 25, 17, 30, 42), 3343, 384, datetime.datetime(2005, 6, 3, 22, 36, 42), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (104, datetime.datetime(2005, 5, 25, 17, 46, 33), 4281, 310, datetime.datetime(2005, 5, 27, 15, 20, 33), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (105, datetime.datetime(2005, 5, 25, 17, 54, 12), 794, 108, datetime.datetime(2005, 5, 30, 12, 3, 12), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (106, datetime.datetime(2005, 5, 25, 18, 18, 19), 3627, 196, datetime.datetime(2005, 6, 4, 0, 1, 19), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (107, datetime.datetime(2005, 5, 25, 18, 28, 9), 2833, 317, datetime.datetime(2005, 6, 3, 22, 46, 9), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (108, datetime.datetime(2005, 5, 25, 18, 30, 5), 3289, 242, datetime.datetime(2005, 5, 30, 19, 40, 5), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (109, datetime.datetime(2005, 5, 25, 18, 40, 20), 1044, 503, datetime.datetime(2005, 5, 29, 20, 39, 20), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (110, datetime.datetime(2005, 5, 25, 18, 43, 49), 4108, 19, datetime.datetime(2005, 6, 3, 18, 13, 49), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (111, datetime.datetime(2005, 5, 25, 18, 45, 19), 3725, 227, datetime.datetime(2005, 5, 28, 17, 18, 19), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (112, datetime.datetime(2005, 5, 25, 18, 57, 24), 2153, 500, datetime.datetime(2005, 6, 2, 20, 44, 24), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (113, datetime.datetime(2005, 5, 25, 19, 7, 40), 2963, 93, datetime.datetime(2005, 5, 27, 22, 16, 40), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (114, datetime.datetime(2005, 5, 25, 19, 12, 42), 4502, 506, datetime.datetime(2005, 6, 1, 23, 10, 42), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (115, datetime.datetime(2005, 5, 25, 19, 13, 25), 749, 455, datetime.datetime(2005, 5, 29, 20, 17, 25), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (116, datetime.datetime(2005, 5, 25, 19, 27, 51), 4453, 18, datetime.datetime(2005, 5, 26, 16, 23, 51), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (117, datetime.datetime(2005, 5, 25, 19, 30, 46), 4278, 7, datetime.datetime(2005, 5, 31, 23, 59, 46), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (118, datetime.datetime(2005, 5, 25, 19, 31, 18), 872, 524, datetime.datetime(2005, 5, 31, 15, 0, 18), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (119, datetime.datetime(2005, 5, 25, 19, 37, 2), 1359, 51, datetime.datetime(2005, 5, 29, 23, 51, 2), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (120, datetime.datetime(2005, 5, 25, 19, 37, 47), 37, 365, datetime.datetime(2005, 6, 1, 23, 29, 47), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (121, datetime.datetime(2005, 5, 25, 19, 41, 29), 1053, 405, datetime.datetime(2005, 5, 29, 21, 31, 29), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (122, datetime.datetime(2005, 5, 25, 19, 46, 21), 2908, 273, datetime.datetime(2005, 6, 2, 19, 7, 21), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (123, datetime.datetime(2005, 5, 25, 20, 26, 42), 1795, 43, datetime.datetime(2005, 5, 26, 19, 41, 42), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (124, datetime.datetime(2005, 5, 25, 20, 46, 11), 212, 246, datetime.datetime(2005, 5, 30, 0, 47, 11), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (125, datetime.datetime(2005, 5, 25, 20, 48, 50), 952, 368, datetime.datetime(2005, 6, 2, 21, 39, 50), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (126, datetime.datetime(2005, 5, 25, 21, 7, 59), 2047, 439, datetime.datetime(2005, 5, 28, 18, 51, 59), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (127, datetime.datetime(2005, 5, 25, 21, 10, 40), 2026, 94, datetime.datetime(2005, 6, 2, 21, 38, 40), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (128, datetime.datetime(2005, 5, 25, 21, 19, 53), 4322, 40, datetime.datetime(2005, 5, 29, 23, 34, 53), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (129, datetime.datetime(2005, 5, 25, 21, 20, 3), 4154, 23, datetime.datetime(2005, 6, 4, 1, 25, 3), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (130, datetime.datetime(2005, 5, 25, 21, 21, 56), 3990, 56, datetime.datetime(2005, 5, 30, 22, 41, 56), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (131, datetime.datetime(2005, 5, 25, 21, 42, 46), 815, 325, datetime.datetime(2005, 5, 30, 23, 25, 46), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (132, datetime.datetime(2005, 5, 25, 21, 46, 54), 3367, 479, datetime.datetime(2005, 5, 31, 21, 2, 54), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (133, datetime.datetime(2005, 5, 25, 21, 48, 30), 399, 237, datetime.datetime(2005, 5, 30, 0, 26, 30), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (134, datetime.datetime(2005, 5, 25, 21, 48, 41), 2272, 222, datetime.datetime(2005, 6, 2, 18, 28, 41), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (135, datetime.datetime(2005, 5, 25, 21, 58, 58), 103, 304, datetime.datetime(2005, 6, 3, 17, 50, 58), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (136, datetime.datetime(2005, 5, 25, 22, 2, 30), 2296, 504, datetime.datetime(2005, 5, 31, 18, 6, 30), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (137, datetime.datetime(2005, 5, 25, 22, 25, 18), 2591, 560, datetime.datetime(2005, 6, 1, 2, 30, 18), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (138, datetime.datetime(2005, 5, 25, 22, 48, 22), 4134, 586, datetime.datetime(2005, 5, 29, 20, 21, 22), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (139, datetime.datetime(2005, 5, 25, 23, 0, 21), 327, 257, datetime.datetime(2005, 5, 29, 17, 12, 21), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (140, datetime.datetime(2005, 5, 25, 23, 34, 22), 655, 354, datetime.datetime(2005, 5, 27, 1, 10, 22), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (141, datetime.datetime(2005, 5, 25, 23, 34, 53), 811, 89, datetime.datetime(2005, 6, 2, 1, 57, 53), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (142, datetime.datetime(2005, 5, 25, 23, 43, 47), 4407, 472, datetime.datetime(2005, 5, 29, 0, 46, 47), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (143, datetime.datetime(2005, 5, 25, 23, 45, 52), 847, 297, datetime.datetime(2005, 5, 27, 21, 41, 52), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (144, datetime.datetime(2005, 5, 25, 23, 49, 56), 1689, 357, datetime.datetime(2005, 6, 1, 21, 41, 56), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (145, datetime.datetime(2005, 5, 25, 23, 59, 3), 3905, 82, datetime.datetime(2005, 5, 31, 2, 56, 3), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (146, datetime.datetime(2005, 5, 26, 0, 7, 11), 1431, 433, datetime.datetime(2005, 6, 4, 0, 20, 11), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (147, datetime.datetime(2005, 5, 26, 0, 17, 50), 633, 274, datetime.datetime(2005, 5, 29, 23, 21, 50), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (148, datetime.datetime(2005, 5, 26, 0, 25, 23), 4252, 142, datetime.datetime(2005, 6, 1, 19, 29, 23), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (149, datetime.datetime(2005, 5, 26, 0, 28, 5), 1084, 319, datetime.datetime(2005, 6, 2, 21, 30, 5), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (150, datetime.datetime(2005, 5, 26, 0, 28, 39), 909, 429, datetime.datetime(2005, 6, 1, 2, 10, 39), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (151, datetime.datetime(2005, 5, 26, 0, 37, 28), 2942, 14, datetime.datetime(2005, 5, 30, 6, 28, 28), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (152, datetime.datetime(2005, 5, 26, 0, 41, 10), 2622, 57, datetime.datetime(2005, 6, 3, 6, 5, 10), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (153, datetime.datetime(2005, 5, 26, 0, 47, 47), 3888, 348, datetime.datetime(2005, 5, 27, 21, 28, 47), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (154, datetime.datetime(2005, 5, 26, 0, 55, 56), 1354, 185, datetime.datetime(2005, 5, 29, 23, 18, 56), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (155, datetime.datetime(2005, 5, 26, 1, 15, 5), 288, 551, datetime.datetime(2005, 6, 1, 0, 3, 5), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (156, datetime.datetime(2005, 5, 26, 1, 19, 5), 3193, 462, datetime.datetime(2005, 5, 27, 23, 43, 5), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (157, datetime.datetime(2005, 5, 26, 1, 25, 21), 887, 344, datetime.datetime(2005, 5, 26, 21, 17, 21), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (158, datetime.datetime(2005, 5, 26, 1, 27, 11), 2395, 354, datetime.datetime(2005, 6, 3, 0, 30, 11), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (159, datetime.datetime(2005, 5, 26, 1, 34, 28), 3453, 505, datetime.datetime(2005, 5, 29, 4, 0, 28), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (160, datetime.datetime(2005, 5, 26, 1, 46, 20), 1885, 290, datetime.datetime(2005, 6, 1, 5, 45, 20), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (161, datetime.datetime(2005, 5, 26, 1, 51, 48), 2941, 182, datetime.datetime(2005, 5, 27, 5, 42, 48), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (162, datetime.datetime(2005, 5, 26, 2, 2, 5), 1229, 296, datetime.datetime(2005, 5, 27, 3, 38, 5), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (163, datetime.datetime(2005, 5, 26, 2, 26, 23), 2306, 104, datetime.datetime(2005, 6, 4, 6, 36, 23), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (164, datetime.datetime(2005, 5, 26, 2, 26, 49), 1070, 151, datetime.datetime(2005, 5, 28, 0, 32, 49), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (165, datetime.datetime(2005, 5, 26, 2, 28, 36), 2735, 33, datetime.datetime(2005, 6, 2, 3, 21, 36), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (166, datetime.datetime(2005, 5, 26, 2, 49, 11), 3894, 322, datetime.datetime(2005, 5, 31, 1, 28, 11), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (167, datetime.datetime(2005, 5, 26, 2, 50, 31), 865, 401, datetime.datetime(2005, 5, 27, 3, 7, 31), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (168, datetime.datetime(2005, 5, 26, 3, 7, 43), 2714, 469, datetime.datetime(2005, 6, 2, 2, 9, 43), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (169, datetime.datetime(2005, 5, 26, 3, 9, 30), 1758, 381, datetime.datetime(2005, 5, 27, 1, 37, 30), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (170, datetime.datetime(2005, 5, 26, 3, 11, 12), 3688, 107, datetime.datetime(2005, 6, 2, 3, 53, 12), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (171, datetime.datetime(2005, 5, 26, 3, 14, 15), 4483, 400, datetime.datetime(2005, 6, 3, 0, 24, 15), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (172, datetime.datetime(2005, 5, 26, 3, 17, 42), 2873, 176, datetime.datetime(2005, 5, 29, 4, 11, 42), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (173, datetime.datetime(2005, 5, 26, 3, 42, 10), 3596, 533, datetime.datetime(2005, 5, 28, 1, 37, 10), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (174, datetime.datetime(2005, 5, 26, 3, 44, 10), 3954, 552, datetime.datetime(2005, 5, 28, 7, 13, 10), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (175, datetime.datetime(2005, 5, 26, 3, 46, 26), 4346, 47, datetime.datetime(2005, 6, 3, 6, 1, 26), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (176, datetime.datetime(2005, 5, 26, 3, 47, 39), 851, 250, datetime.datetime(2005, 6, 1, 2, 36, 39), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (177, datetime.datetime(2005, 5, 26, 4, 14, 29), 3545, 548, datetime.datetime(2005, 6, 1, 8, 16, 29), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (178, datetime.datetime(2005, 5, 26, 4, 21, 46), 1489, 196, datetime.datetime(2005, 6, 4, 7, 9, 46), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (179, datetime.datetime(2005, 5, 26, 4, 26, 6), 2575, 19, datetime.datetime(2005, 6, 3, 10, 6, 6), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (180, datetime.datetime(2005, 5, 26, 4, 46, 23), 2752, 75, datetime.datetime(2005, 6, 1, 9, 58, 23), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (181, datetime.datetime(2005, 5, 26, 4, 47, 6), 2417, 587, datetime.datetime(2005, 5, 29, 6, 34, 6), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (182, datetime.datetime(2005, 5, 26, 4, 49, 17), 4396, 237, datetime.datetime(2005, 6, 1, 5, 43, 17), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (183, datetime.datetime(2005, 5, 26, 5, 1, 18), 2877, 254, datetime.datetime(2005, 6, 1, 9, 4, 18), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (184, datetime.datetime(2005, 5, 26, 5, 29, 49), 1970, 556, datetime.datetime(2005, 5, 28, 10, 10, 49), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (185, datetime.datetime(2005, 5, 26, 5, 30, 3), 2598, 125, datetime.datetime(2005, 6, 2, 9, 48, 3), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (186, datetime.datetime(2005, 5, 26, 5, 32, 52), 1799, 468, datetime.datetime(2005, 6, 3, 7, 19, 52), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (187, datetime.datetime(2005, 5, 26, 5, 42, 37), 4004, 515, datetime.datetime(2005, 6, 4, 0, 38, 37), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (188, datetime.datetime(2005, 5, 26, 5, 47, 12), 3342, 243, datetime.datetime(2005, 5, 26, 23, 48, 12), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (189, datetime.datetime(2005, 5, 26, 6, 1, 41), 984, 247, datetime.datetime(2005, 5, 27, 6, 11, 41), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (190, datetime.datetime(2005, 5, 26, 6, 11, 28), 3962, 533, datetime.datetime(2005, 6, 1, 9, 44, 28), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (191, datetime.datetime(2005, 5, 26, 6, 14, 6), 4365, 412, datetime.datetime(2005, 5, 28, 5, 33, 6), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (192, datetime.datetime(2005, 5, 26, 6, 20, 37), 1897, 437, datetime.datetime(2005, 6, 2, 10, 57, 37), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (193, datetime.datetime(2005, 5, 26, 6, 41, 48), 3900, 270, datetime.datetime(2005, 5, 30, 6, 21, 48), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (194, datetime.datetime(2005, 5, 26, 6, 52, 33), 1337, 29, datetime.datetime(2005, 5, 30, 4, 8, 33), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (195, datetime.datetime(2005, 5, 26, 6, 52, 36), 506, 564, datetime.datetime(2005, 5, 31, 2, 47, 36), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (196, datetime.datetime(2005, 5, 26, 6, 55, 58), 190, 184, datetime.datetime(2005, 5, 27, 10, 54, 58), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (197, datetime.datetime(2005, 5, 26, 6, 59, 21), 4212, 546, datetime.datetime(2005, 6, 3, 5, 4, 21), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (198, datetime.datetime(2005, 5, 26, 7, 3, 49), 1789, 54, datetime.datetime(2005, 6, 4, 11, 45, 49), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (199, datetime.datetime(2005, 5, 26, 7, 11, 58), 2135, 71, datetime.datetime(2005, 5, 28, 9, 6, 58), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (200, datetime.datetime(2005, 5, 26, 7, 12, 21), 3926, 321, datetime.datetime(2005, 5, 31, 12, 7, 21), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (201, datetime.datetime(2005, 5, 26, 7, 13, 45), 776, 444, datetime.datetime(2005, 6, 4, 2, 2, 45), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (202, datetime.datetime(2005, 5, 26, 7, 27, 36), 674, 20, datetime.datetime(2005, 6, 2, 3, 52, 36), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (203, datetime.datetime(2005, 5, 26, 7, 27, 57), 3374, 109, datetime.datetime(2005, 6, 3, 12, 52, 57), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (204, datetime.datetime(2005, 5, 26, 7, 30, 37), 1842, 528, datetime.datetime(2005, 5, 30, 8, 11, 37), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (205, datetime.datetime(2005, 5, 26, 7, 59, 37), 303, 114, datetime.datetime(2005, 5, 29, 9, 43, 37), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (206, datetime.datetime(2005, 5, 26, 8, 1, 54), 1717, 345, datetime.datetime(2005, 5, 27, 6, 26, 54), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (207, datetime.datetime(2005, 5, 26, 8, 4, 38), 102, 47, datetime.datetime(2005, 5, 27, 9, 32, 38), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (208, datetime.datetime(2005, 5, 26, 8, 10, 22), 3669, 274, datetime.datetime(2005, 5, 27, 3, 55, 22), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (209, datetime.datetime(2005, 5, 26, 8, 14, 1), 729, 379, datetime.datetime(2005, 5, 27, 9, 0, 1), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (210, datetime.datetime(2005, 5, 26, 8, 14, 15), 1801, 391, datetime.datetime(2005, 5, 27, 12, 12, 15), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (211, datetime.datetime(2005, 5, 26, 8, 33, 10), 4005, 170, datetime.datetime(2005, 5, 28, 14, 9, 10), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (212, datetime.datetime(2005, 5, 26, 8, 34, 41), 764, 59, datetime.datetime(2005, 5, 30, 12, 46, 41), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (213, datetime.datetime(2005, 5, 26, 8, 44, 8), 1505, 394, datetime.datetime(2005, 5, 31, 12, 33, 8), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (214, datetime.datetime(2005, 5, 26, 8, 48, 49), 1453, 98, datetime.datetime(2005, 5, 31, 4, 6, 49), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (215, datetime.datetime(2005, 5, 26, 9, 2, 47), 679, 197, datetime.datetime(2005, 5, 28, 9, 45, 47), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (216, datetime.datetime(2005, 5, 26, 9, 17, 43), 1398, 91, datetime.datetime(2005, 6, 3, 8, 21, 43), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (217, datetime.datetime(2005, 5, 26, 9, 24, 26), 4395, 121, datetime.datetime(2005, 5, 31, 3, 24, 26), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (218, datetime.datetime(2005, 5, 26, 9, 27, 9), 2291, 309, datetime.datetime(2005, 6, 4, 11, 53, 9), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (219, datetime.datetime(2005, 5, 26, 9, 41, 45), 3074, 489, datetime.datetime(2005, 5, 28, 4, 40, 45), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (220, datetime.datetime(2005, 5, 26, 10, 6, 49), 1259, 542, datetime.datetime(2005, 6, 1, 7, 43, 49), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (221, datetime.datetime(2005, 5, 26, 10, 14, 9), 3578, 143, datetime.datetime(2005, 5, 29, 5, 57, 9), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (222, datetime.datetime(2005, 5, 26, 10, 14, 38), 2745, 83, datetime.datetime(2005, 5, 31, 8, 36, 38), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (223, datetime.datetime(2005, 5, 26, 10, 15, 23), 3121, 460, datetime.datetime(2005, 5, 30, 11, 43, 23), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (224, datetime.datetime(2005, 5, 26, 10, 18, 27), 4285, 318, datetime.datetime(2005, 6, 4, 6, 59, 27), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (225, datetime.datetime(2005, 5, 26, 10, 27, 50), 651, 467, datetime.datetime(2005, 6, 1, 7, 1, 50), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (226, datetime.datetime(2005, 5, 26, 10, 44, 4), 4181, 221, datetime.datetime(2005, 5, 31, 13, 26, 4), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (227, datetime.datetime(2005, 5, 26, 10, 51, 46), 214, 301, datetime.datetime(2005, 5, 30, 7, 24, 46), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (228, datetime.datetime(2005, 5, 26, 10, 54, 28), 511, 571, datetime.datetime(2005, 6, 4, 9, 39, 28), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (229, datetime.datetime(2005, 5, 26, 11, 19, 20), 1131, 312, datetime.datetime(2005, 5, 31, 11, 56, 20), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (230, datetime.datetime(2005, 5, 26, 11, 31, 50), 1085, 58, datetime.datetime(2005, 5, 30, 15, 22, 50), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (231, datetime.datetime(2005, 5, 26, 11, 31, 59), 4032, 365, datetime.datetime(2005, 5, 27, 7, 27, 59), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (232, datetime.datetime(2005, 5, 26, 11, 38, 5), 2945, 256, datetime.datetime(2005, 5, 27, 8, 42, 5), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (233, datetime.datetime(2005, 5, 26, 11, 43, 44), 715, 531, datetime.datetime(2005, 5, 28, 17, 28, 44), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (234, datetime.datetime(2005, 5, 26, 11, 47, 20), 1321, 566, datetime.datetime(2005, 6, 3, 10, 39, 20), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (235, datetime.datetime(2005, 5, 26, 11, 51, 9), 3537, 119, datetime.datetime(2005, 6, 4, 9, 36, 9), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (236, datetime.datetime(2005, 5, 26, 11, 53, 49), 1265, 446, datetime.datetime(2005, 5, 28, 13, 55, 49), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (237, datetime.datetime(2005, 5, 26, 12, 15, 13), 241, 536, datetime.datetime(2005, 5, 29, 18, 10, 13), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (238, datetime.datetime(2005, 5, 26, 12, 30, 22), 503, 211, datetime.datetime(2005, 5, 27, 6, 49, 22), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (239, datetime.datetime(2005, 5, 26, 12, 30, 26), 131, 49, datetime.datetime(2005, 6, 1, 13, 26, 26), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (240, datetime.datetime(2005, 5, 26, 12, 40, 23), 3420, 103, datetime.datetime(2005, 6, 4, 7, 22, 23), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (241, datetime.datetime(2005, 5, 26, 12, 49, 1), 4438, 245, datetime.datetime(2005, 5, 28, 11, 43, 1), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (242, datetime.datetime(2005, 5, 26, 13, 5, 8), 2095, 214, datetime.datetime(2005, 6, 2, 15, 26, 8), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (243, datetime.datetime(2005, 5, 26, 13, 6, 5), 1721, 543, datetime.datetime(2005, 6, 3, 17, 28, 5), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (244, datetime.datetime(2005, 5, 26, 13, 40, 40), 1041, 257, datetime.datetime(2005, 5, 31, 11, 58, 40), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (245, datetime.datetime(2005, 5, 26, 13, 46, 59), 3045, 158, datetime.datetime(2005, 5, 27, 9, 58, 59), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (246, datetime.datetime(2005, 5, 26, 13, 57, 7), 2829, 240, datetime.datetime(2005, 5, 29, 10, 12, 7), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (247, datetime.datetime(2005, 5, 26, 14, 1, 5), 4095, 102, datetime.datetime(2005, 5, 28, 13, 38, 5), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (248, datetime.datetime(2005, 5, 26, 14, 7, 58), 1913, 545, datetime.datetime(2005, 5, 31, 14, 3, 58), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (249, datetime.datetime(2005, 5, 26, 14, 19, 9), 2428, 472, datetime.datetime(2005, 5, 28, 17, 47, 9), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (250, datetime.datetime(2005, 5, 26, 14, 30, 24), 368, 539, datetime.datetime(2005, 5, 27, 8, 50, 24), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (251, datetime.datetime(2005, 5, 26, 14, 35, 40), 4352, 204, datetime.datetime(2005, 5, 29, 17, 17, 40), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (252, datetime.datetime(2005, 5, 26, 14, 39, 53), 1203, 187, datetime.datetime(2005, 6, 2, 14, 48, 53), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (253, datetime.datetime(2005, 5, 26, 14, 43, 14), 2969, 416, datetime.datetime(2005, 5, 27, 12, 21, 14), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (254, datetime.datetime(2005, 5, 26, 14, 43, 48), 1835, 390, datetime.datetime(2005, 5, 31, 9, 19, 48), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (255, datetime.datetime(2005, 5, 26, 14, 52, 15), 3264, 114, datetime.datetime(2005, 5, 27, 12, 45, 15), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (256, datetime.datetime(2005, 5, 26, 15, 20, 58), 3194, 436, datetime.datetime(2005, 5, 31, 15, 58, 58), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (257, datetime.datetime(2005, 5, 26, 15, 27, 5), 2570, 373, datetime.datetime(2005, 5, 29, 16, 25, 5), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (258, datetime.datetime(2005, 5, 26, 15, 28, 14), 3534, 502, datetime.datetime(2005, 5, 30, 18, 38, 14), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (259, datetime.datetime(2005, 5, 26, 15, 32, 46), 30, 482, datetime.datetime(2005, 6, 4, 15, 27, 46), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (260, datetime.datetime(2005, 5, 26, 15, 42, 20), 435, 21, datetime.datetime(2005, 5, 31, 13, 21, 20), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (261, datetime.datetime(2005, 5, 26, 15, 44, 23), 1369, 414, datetime.datetime(2005, 6, 2, 9, 47, 23), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (262, datetime.datetime(2005, 5, 26, 15, 46, 56), 4261, 236, datetime.datetime(2005, 5, 28, 15, 49, 56), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (263, datetime.datetime(2005, 5, 26, 15, 47, 40), 1160, 449, datetime.datetime(2005, 5, 30, 10, 7, 40), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (264, datetime.datetime(2005, 5, 26, 16, 0, 49), 2069, 251, datetime.datetime(2005, 5, 27, 10, 12, 49), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (265, datetime.datetime(2005, 5, 26, 16, 7, 38), 2276, 303, datetime.datetime(2005, 6, 1, 14, 20, 38), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (266, datetime.datetime(2005, 5, 26, 16, 8, 5), 3303, 263, datetime.datetime(2005, 5, 27, 10, 55, 5), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (267, datetime.datetime(2005, 5, 26, 16, 16, 21), 1206, 417, datetime.datetime(2005, 5, 30, 16, 53, 21), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (268, datetime.datetime(2005, 5, 26, 16, 19, 8), 1714, 75, datetime.datetime(2005, 5, 27, 14, 35, 8), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (269, datetime.datetime(2005, 5, 26, 16, 19, 46), 3501, 322, datetime.datetime(2005, 5, 27, 15, 59, 46), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (270, datetime.datetime(2005, 5, 26, 16, 20, 56), 207, 200, datetime.datetime(2005, 6, 3, 12, 40, 56), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (271, datetime.datetime(2005, 5, 26, 16, 22, 1), 2388, 92, datetime.datetime(2005, 6, 3, 17, 30, 1), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (272, datetime.datetime(2005, 5, 26, 16, 27, 11), 971, 71, datetime.datetime(2005, 6, 3, 13, 10, 11), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (273, datetime.datetime(2005, 5, 26, 16, 29, 36), 1590, 193, datetime.datetime(2005, 5, 29, 18, 49, 36), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (274, datetime.datetime(2005, 5, 26, 16, 48, 51), 656, 311, datetime.datetime(2005, 6, 3, 18, 17, 51), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (275, datetime.datetime(2005, 5, 26, 17, 9, 53), 1718, 133, datetime.datetime(2005, 6, 4, 22, 35, 53), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (276, datetime.datetime(2005, 5, 26, 17, 16, 7), 1221, 58, datetime.datetime(2005, 6, 3, 12, 59, 7), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (277, datetime.datetime(2005, 5, 26, 17, 32, 11), 1409, 45, datetime.datetime(2005, 5, 28, 22, 54, 11), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (278, datetime.datetime(2005, 5, 26, 17, 40, 58), 182, 214, datetime.datetime(2005, 6, 2, 16, 43, 58), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (279, datetime.datetime(2005, 5, 26, 18, 2, 50), 661, 384, datetime.datetime(2005, 6, 3, 18, 48, 50), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (280, datetime.datetime(2005, 5, 26, 18, 36, 58), 1896, 167, datetime.datetime(2005, 5, 27, 23, 42, 58), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (281, datetime.datetime(2005, 5, 26, 18, 49, 35), 1208, 582, datetime.datetime(2005, 5, 27, 18, 11, 35), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (282, datetime.datetime(2005, 5, 26, 18, 56, 26), 4486, 282, datetime.datetime(2005, 6, 1, 16, 32, 26), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (283, datetime.datetime(2005, 5, 26, 19, 5, 5), 3530, 242, datetime.datetime(2005, 5, 31, 19, 19, 5), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (284, datetime.datetime(2005, 5, 26, 19, 21, 44), 350, 359, datetime.datetime(2005, 6, 4, 14, 18, 44), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (285, datetime.datetime(2005, 5, 26, 19, 41, 40), 2486, 162, datetime.datetime(2005, 5, 31, 16, 58, 40), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (286, datetime.datetime(2005, 5, 26, 19, 44, 51), 314, 371, datetime.datetime(2005, 6, 4, 18, 0, 51), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (287, datetime.datetime(2005, 5, 26, 19, 44, 54), 3631, 17, datetime.datetime(2005, 6, 2, 1, 10, 54), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (288, datetime.datetime(2005, 5, 26, 19, 47, 49), 3546, 82, datetime.datetime(2005, 6, 3, 20, 53, 49), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (289, datetime.datetime(2005, 5, 26, 20, 1, 9), 2449, 81, datetime.datetime(2005, 5, 28, 15, 9, 9), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (290, datetime.datetime(2005, 5, 26, 20, 8, 33), 2776, 429, datetime.datetime(2005, 5, 30, 0, 32, 33), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (291, datetime.datetime(2005, 5, 26, 20, 20, 47), 485, 577, datetime.datetime(2005, 6, 3, 2, 6, 47), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (292, datetime.datetime(2005, 5, 26, 20, 22, 12), 4264, 515, datetime.datetime(2005, 6, 5, 0, 58, 12), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (293, datetime.datetime(2005, 5, 26, 20, 27, 2), 1828, 158, datetime.datetime(2005, 6, 3, 16, 45, 2), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (294, datetime.datetime(2005, 5, 26, 20, 29, 57), 2751, 369, datetime.datetime(2005, 5, 28, 17, 20, 57), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (295, datetime.datetime(2005, 5, 26, 20, 33, 20), 4030, 65, datetime.datetime(2005, 5, 27, 18, 23, 20), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (296, datetime.datetime(2005, 5, 26, 20, 35, 19), 3878, 468, datetime.datetime(2005, 6, 4, 2, 31, 19), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (297, datetime.datetime(2005, 5, 26, 20, 48, 48), 1594, 48, datetime.datetime(2005, 5, 27, 19, 52, 48), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (298, datetime.datetime(2005, 5, 26, 20, 52, 26), 1083, 460, datetime.datetime(2005, 5, 29, 22, 8, 26), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (299, datetime.datetime(2005, 5, 26, 20, 55, 36), 4376, 448, datetime.datetime(2005, 5, 28, 0, 25, 36), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (300, datetime.datetime(2005, 5, 26, 20, 57), 249, 47, datetime.datetime(2005, 6, 5, 1, 34), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (301, datetime.datetime(2005, 5, 26, 21, 6, 14), 3448, 274, datetime.datetime(2005, 6, 1, 1, 54, 14), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (302, datetime.datetime(2005, 5, 26, 21, 13, 46), 2921, 387, datetime.datetime(2005, 6, 3, 15, 49, 46), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (303, datetime.datetime(2005, 5, 26, 21, 16, 52), 1111, 596, datetime.datetime(2005, 5, 27, 23, 41, 52), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (304, datetime.datetime(2005, 5, 26, 21, 21, 28), 1701, 534, datetime.datetime(2005, 6, 2, 0, 5, 28), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (305, datetime.datetime(2005, 5, 26, 21, 22, 7), 2665, 464, datetime.datetime(2005, 6, 2, 22, 33, 7), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (306, datetime.datetime(2005, 5, 26, 21, 31, 57), 2781, 547, datetime.datetime(2005, 5, 28, 19, 37, 57), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (307, datetime.datetime(2005, 5, 26, 21, 48, 13), 1097, 375, datetime.datetime(2005, 6, 4, 22, 24, 13), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (308, datetime.datetime(2005, 5, 26, 22, 1, 39), 187, 277, datetime.datetime(2005, 6, 4, 20, 24, 39), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (309, datetime.datetime(2005, 5, 26, 22, 38, 10), 1946, 251, datetime.datetime(2005, 6, 2, 3, 10, 10), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (310, datetime.datetime(2005, 5, 26, 22, 41, 7), 593, 409, datetime.datetime(2005, 6, 2, 4, 9, 7), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (311, datetime.datetime(2005, 5, 26, 22, 51, 37), 2830, 201, datetime.datetime(2005, 6, 1, 0, 2, 37), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (312, datetime.datetime(2005, 5, 26, 22, 52, 19), 2008, 143, datetime.datetime(2005, 6, 2, 18, 14, 19), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (313, datetime.datetime(2005, 5, 26, 22, 56, 19), 4156, 594, datetime.datetime(2005, 5, 29, 1, 29, 19), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (314, datetime.datetime(2005, 5, 26, 23, 9, 41), 2851, 203, datetime.datetime(2005, 5, 28, 22, 49, 41), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (315, datetime.datetime(2005, 5, 26, 23, 12, 55), 2847, 238, datetime.datetime(2005, 5, 29, 23, 33, 55), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (316, datetime.datetime(2005, 5, 26, 23, 22, 55), 3828, 249, datetime.datetime(2005, 5, 29, 23, 25, 55), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
# ...
#  (897, datetime.datetime(2005, 5, 30, 9, 10, 1), 1334, 432, datetime.datetime(2005, 6, 8, 3, 43, 1), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (898, datetime.datetime(2005, 5, 30, 9, 26, 19), 3497, 384, datetime.datetime(2005, 6, 1, 10, 45, 19), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (899, datetime.datetime(2005, 5, 30, 9, 29, 30), 1096, 156, datetime.datetime(2005, 6, 6, 12, 39, 30), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (900, datetime.datetime(2005, 5, 30, 9, 38, 41), 3543, 586, datetime.datetime(2005, 6, 7, 11, 54, 41), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (901, datetime.datetime(2005, 5, 30, 9, 40, 40), 760, 259, datetime.datetime(2005, 6, 2, 10, 32, 40), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (902, datetime.datetime(2005, 5, 30, 9, 53, 36), 1514, 561, datetime.datetime(2005, 6, 7, 12, 10, 36), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (903, datetime.datetime(2005, 5, 30, 10, 11, 29), 2423, 197, datetime.datetime(2005, 6, 3, 9, 33, 29), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (904, datetime.datetime(2005, 5, 30, 10, 19, 42), 2466, 44, datetime.datetime(2005, 6, 5, 4, 58, 42), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (905, datetime.datetime(2005, 5, 30, 10, 25), 4372, 50, datetime.datetime(2005, 6, 6, 6, 23), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (906, datetime.datetime(2005, 5, 30, 10, 30, 38), 1862, 549, datetime.datetime(2005, 6, 7, 6, 44, 38), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (907, datetime.datetime(2005, 5, 30, 10, 37, 27), 3320, 506, datetime.datetime(2005, 6, 2, 9, 51, 27), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (908, datetime.datetime(2005, 5, 30, 10, 38, 37), 4427, 85, datetime.datetime(2005, 6, 3, 9, 56, 37), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (909, datetime.datetime(2005, 5, 30, 10, 43, 38), 3775, 486, datetime.datetime(2005, 6, 8, 12, 7, 38), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (910, datetime.datetime(2005, 5, 30, 10, 46, 16), 2601, 374, datetime.datetime(2005, 6, 4, 13, 32, 16), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (911, datetime.datetime(2005, 5, 30, 10, 50, 22), 1404, 366, datetime.datetime(2005, 6, 7, 12, 26, 22), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (912, datetime.datetime(2005, 5, 30, 10, 58, 33), 3200, 390, datetime.datetime(2005, 5, 31, 9, 31, 33), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (913, datetime.datetime(2005, 5, 30, 11, 4, 58), 3213, 369, datetime.datetime(2005, 6, 7, 13, 22, 58), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (914, datetime.datetime(2005, 5, 30, 11, 6), 1393, 596, datetime.datetime(2005, 6, 4, 6, 7), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (915, datetime.datetime(2005, 5, 30, 11, 20, 27), 1859, 115, datetime.datetime(2005, 6, 2, 11, 55, 27), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (916, datetime.datetime(2005, 5, 30, 11, 25, 1), 1290, 6, datetime.datetime(2005, 5, 31, 9, 6, 1), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (917, datetime.datetime(2005, 5, 30, 11, 27, 6), 3629, 385, datetime.datetime(2005, 6, 2, 8, 31, 6), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (918, datetime.datetime(2005, 5, 30, 11, 32, 24), 818, 197, datetime.datetime(2005, 5, 31, 7, 55, 24), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (919, datetime.datetime(2005, 5, 30, 11, 35, 6), 4052, 374, datetime.datetime(2005, 6, 2, 13, 16, 6), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (920, datetime.datetime(2005, 5, 30, 11, 44, 1), 3860, 584, datetime.datetime(2005, 6, 2, 8, 19, 1), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (921, datetime.datetime(2005, 5, 30, 11, 53, 9), 1827, 508, datetime.datetime(2005, 6, 3, 10, 0, 9), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (922, datetime.datetime(2005, 5, 30, 11, 55, 55), 2442, 550, datetime.datetime(2005, 6, 8, 10, 12, 55), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (923, datetime.datetime(2005, 5, 30, 11, 58, 50), 1884, 37, datetime.datetime(2005, 6, 5, 9, 57, 50), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (924, datetime.datetime(2005, 5, 30, 12, 10, 59), 3279, 293, datetime.datetime(2005, 6, 4, 17, 28, 59), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (925, datetime.datetime(2005, 5, 30, 12, 13, 52), 3203, 137, datetime.datetime(2005, 6, 2, 14, 41, 52), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (926, datetime.datetime(2005, 5, 30, 12, 15, 54), 4327, 76, datetime.datetime(2005, 6, 1, 8, 53, 54), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (927, datetime.datetime(2005, 5, 30, 12, 16, 40), 1158, 167, datetime.datetime(2005, 5, 31, 16, 20, 40), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (928, datetime.datetime(2005, 5, 30, 12, 27, 14), 246, 79, datetime.datetime(2005, 6, 5, 13, 56, 14), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (929, datetime.datetime(2005, 5, 30, 12, 32, 39), 4296, 536, datetime.datetime(2005, 6, 6, 12, 17, 39), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (930, datetime.datetime(2005, 5, 30, 12, 44, 57), 2835, 141, datetime.datetime(2005, 6, 4, 10, 53, 57), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (931, datetime.datetime(2005, 5, 30, 12, 53, 1), 3384, 421, datetime.datetime(2005, 5, 31, 14, 28, 1), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (932, datetime.datetime(2005, 5, 30, 12, 55, 36), 719, 198, datetime.datetime(2005, 5, 31, 10, 30, 36), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (933, datetime.datetime(2005, 5, 30, 13, 8, 45), 3672, 66, datetime.datetime(2005, 6, 1, 18, 56, 45), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (934, datetime.datetime(2005, 5, 30, 13, 24, 46), 3595, 60, datetime.datetime(2005, 6, 8, 16, 44, 46), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (935, datetime.datetime(2005, 5, 30, 13, 29, 36), 2421, 256, datetime.datetime(2005, 6, 2, 11, 8, 36), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (936, datetime.datetime(2005, 5, 30, 13, 52, 49), 901, 469, datetime.datetime(2005, 6, 7, 16, 56, 49), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (937, datetime.datetime(2005, 5, 30, 14, 47, 31), 1054, 304, datetime.datetime(2005, 6, 5, 9, 53, 31), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (938, datetime.datetime(2005, 5, 30, 14, 47, 31), 1521, 46, datetime.datetime(2005, 6, 4, 10, 10, 31), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (939, datetime.datetime(2005, 5, 30, 14, 49, 34), 1314, 367, datetime.datetime(2005, 6, 1, 19, 0, 34), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (940, datetime.datetime(2005, 5, 30, 15, 1, 2), 1278, 534, datetime.datetime(2005, 6, 1, 18, 26, 2), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (941, datetime.datetime(2005, 5, 30, 15, 2, 25), 3630, 562, datetime.datetime(2005, 6, 1, 17, 19, 25), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (942, datetime.datetime(2005, 5, 30, 15, 5, 47), 4279, 473, datetime.datetime(2005, 6, 8, 15, 59, 47), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (943, datetime.datetime(2005, 5, 30, 15, 20, 19), 3737, 57, datetime.datetime(2005, 6, 6, 18, 53, 19), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (944, datetime.datetime(2005, 5, 30, 15, 26, 24), 151, 131, datetime.datetime(2005, 6, 7, 18, 9, 24), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (945, datetime.datetime(2005, 5, 30, 15, 33, 17), 1441, 357, datetime.datetime(2005, 6, 2, 15, 2, 17), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (946, datetime.datetime(2005, 5, 30, 15, 35, 8), 1264, 486, datetime.datetime(2005, 6, 8, 11, 38, 8), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (947, datetime.datetime(2005, 5, 30, 15, 36, 57), 4478, 62, datetime.datetime(2005, 6, 4, 18, 48, 57), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (948, datetime.datetime(2005, 5, 30, 15, 44, 27), 585, 245, datetime.datetime(2005, 6, 8, 17, 30, 27), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (949, datetime.datetime(2005, 5, 30, 15, 50, 39), 2202, 368, datetime.datetime(2005, 6, 3, 14, 25, 39), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (950, datetime.datetime(2005, 5, 30, 16, 6, 8), 491, 83, datetime.datetime(2005, 6, 1, 11, 43, 8), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (951, datetime.datetime(2005, 5, 30, 16, 10, 35), 1395, 59, datetime.datetime(2005, 5, 31, 19, 1, 35), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (952, datetime.datetime(2005, 5, 30, 16, 28, 7), 4389, 311, datetime.datetime(2005, 6, 2, 16, 12, 7), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (953, datetime.datetime(2005, 5, 30, 16, 34, 2), 2194, 210, datetime.datetime(2005, 5, 31, 20, 34, 2), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (954, datetime.datetime(2005, 5, 30, 16, 57, 29), 1231, 297, datetime.datetime(2005, 6, 8, 13, 30, 29), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (955, datetime.datetime(2005, 5, 30, 16, 59, 3), 4140, 301, datetime.datetime(2005, 5, 31, 11, 58, 3), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (956, datetime.datetime(2005, 5, 30, 17, 30, 28), 647, 296, datetime.datetime(2005, 6, 7, 13, 54, 28), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (957, datetime.datetime(2005, 5, 30, 17, 53, 29), 4428, 440, datetime.datetime(2005, 6, 3, 15, 31, 29), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (958, datetime.datetime(2005, 5, 30, 17, 58, 3), 548, 186, datetime.datetime(2005, 6, 1, 19, 17, 3), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (959, datetime.datetime(2005, 5, 30, 18, 7), 3108, 535, datetime.datetime(2005, 6, 2, 14, 37), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (960, datetime.datetime(2005, 5, 30, 18, 13, 23), 1966, 445, datetime.datetime(2005, 6, 4, 0, 12, 23), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (961, datetime.datetime(2005, 5, 30, 18, 16, 44), 3293, 588, datetime.datetime(2005, 6, 4, 23, 40, 44), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (962, datetime.datetime(2005, 5, 30, 18, 45, 17), 4535, 520, datetime.datetime(2005, 6, 5, 22, 47, 17), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (963, datetime.datetime(2005, 5, 30, 18, 52, 53), 1921, 225, datetime.datetime(2005, 6, 7, 16, 19, 53), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (964, datetime.datetime(2005, 5, 30, 18, 53, 21), 657, 287, datetime.datetime(2005, 6, 4, 22, 32, 21), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (965, datetime.datetime(2005, 5, 30, 19, 0, 14), 3363, 502, datetime.datetime(2005, 5, 31, 17, 10, 14), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (966, datetime.datetime(2005, 5, 30, 19, 0, 37), 1294, 496, datetime.datetime(2005, 5, 31, 23, 51, 37), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (967, datetime.datetime(2005, 5, 30, 19, 12, 6), 1954, 330, datetime.datetime(2005, 6, 9, 0, 2, 6), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (968, datetime.datetime(2005, 5, 30, 19, 20, 3), 119, 576, datetime.datetime(2005, 5, 31, 18, 17, 3), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (969, datetime.datetime(2005, 5, 30, 19, 23, 48), 443, 551, datetime.datetime(2005, 5, 31, 21, 14, 48), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (970, datetime.datetime(2005, 5, 30, 19, 50, 28), 1520, 307, datetime.datetime(2005, 6, 9, 1, 19, 28), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (971, datetime.datetime(2005, 5, 30, 20, 10, 52), 2911, 561, datetime.datetime(2005, 6, 6, 20, 47, 52), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (972, datetime.datetime(2005, 5, 30, 20, 21, 7), 2, 411, datetime.datetime(2005, 6, 6, 0, 36, 7), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (973, datetime.datetime(2005, 5, 30, 20, 27, 45), 1914, 473, datetime.datetime(2005, 6, 8, 22, 47, 45), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (974, datetime.datetime(2005, 5, 30, 20, 28, 42), 2617, 596, datetime.datetime(2005, 6, 8, 23, 45, 42), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (975, datetime.datetime(2005, 5, 30, 21, 7, 15), 3109, 7, datetime.datetime(2005, 6, 3, 1, 48, 15), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (976, datetime.datetime(2005, 5, 30, 21, 11, 19), 2290, 581, datetime.datetime(2005, 6, 6, 2, 16, 19), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (977, datetime.datetime(2005, 5, 30, 21, 22, 26), 2029, 394, datetime.datetime(2005, 6, 4, 22, 32, 26), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (978, datetime.datetime(2005, 5, 30, 21, 30, 52), 407, 154, datetime.datetime(2005, 6, 7, 16, 22, 52), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (979, datetime.datetime(2005, 5, 30, 21, 37, 11), 3917, 279, datetime.datetime(2005, 6, 8, 0, 24, 11), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (980, datetime.datetime(2005, 5, 30, 21, 45, 19), 4169, 273, datetime.datetime(2005, 6, 1, 20, 32, 19), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (981, datetime.datetime(2005, 5, 30, 21, 52, 42), 2913, 326, datetime.datetime(2005, 6, 1, 3, 15, 42), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (982, datetime.datetime(2005, 5, 30, 22, 15, 24), 3560, 524, datetime.datetime(2005, 6, 2, 16, 18, 24), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (983, datetime.datetime(2005, 5, 30, 22, 15, 51), 63, 115, datetime.datetime(2005, 6, 2, 22, 56, 51), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (984, datetime.datetime(2005, 5, 30, 22, 17, 17), 2305, 262, datetime.datetime(2005, 6, 1, 20, 15, 17), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (985, datetime.datetime(2005, 5, 30, 22, 18, 35), 1573, 564, datetime.datetime(2005, 6, 4, 23, 36, 35), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (986, datetime.datetime(2005, 5, 30, 22, 22, 52), 4045, 253, datetime.datetime(2005, 6, 1, 2, 24, 52), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (987, datetime.datetime(2005, 5, 30, 22, 59, 12), 390, 11, datetime.datetime(2005, 6, 7, 20, 56, 12), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (988, datetime.datetime(2005, 5, 30, 23, 8, 3), 1364, 12, datetime.datetime(2005, 6, 7, 0, 22, 3), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (989, datetime.datetime(2005, 5, 30, 23, 11, 51), 4388, 83, datetime.datetime(2005, 6, 3, 20, 36, 51), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (990, datetime.datetime(2005, 5, 30, 23, 25, 14), 4171, 311, datetime.datetime(2005, 6, 6, 18, 41, 14), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (991, datetime.datetime(2005, 5, 30, 23, 29, 22), 2863, 593, datetime.datetime(2005, 6, 7, 23, 16, 22), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (992, datetime.datetime(2005, 5, 30, 23, 47, 56), 3572, 123, datetime.datetime(2005, 6, 5, 19, 1, 56), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (993, datetime.datetime(2005, 5, 30, 23, 54, 19), 2080, 513, datetime.datetime(2005, 6, 4, 21, 27, 19), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (994, datetime.datetime(2005, 5, 30, 23, 55, 36), 2798, 472, datetime.datetime(2005, 6, 4, 1, 0, 36), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (995, datetime.datetime(2005, 5, 31, 0, 6, 2), 17, 150, datetime.datetime(2005, 6, 6, 2, 30, 2), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (996, datetime.datetime(2005, 5, 31, 0, 6, 20), 2075, 331, datetime.datetime(2005, 5, 31, 21, 29, 20), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (997, datetime.datetime(2005, 5, 31, 0, 8, 25), 4243, 216, datetime.datetime(2005, 6, 2, 0, 17, 25), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (998, datetime.datetime(2005, 5, 31, 0, 16, 57), 3395, 389, datetime.datetime(2005, 6, 1, 22, 41, 57), 1, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (999, datetime.datetime(2005, 5, 31, 0, 25, 10), 4433, 413, datetime.datetime(2005, 6, 3, 6, 5, 10), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (1000, datetime.datetime(2005, 5, 31, 0, 25, 56), 1774, 332, datetime.datetime(2005, 6, 8, 19, 42, 56), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  (1001, datetime.datetime(2005, 5, 31, 0, 46, 31), 1498, 64, datetime.datetime(2005, 6, 6, 6, 14, 31), 2, datetime.datetime(2006, 2, 15, 21, 30, 53)),
#  ...]
